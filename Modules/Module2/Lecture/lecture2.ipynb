# %% [markdown]
# library(IRdisplay)
# IRdisplay::display_html('<style>th, td { font-size: 25px }</style>')

# %% [markdown]
# # What is probability?
#
#
# -  ### Measure of how likely an event is to occur
# - ### A quantification of uncertainty
# - ### $\frac{outcome}{all-outcomes}$
#
#
#
#
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/coin.jpg?raw=1)
#
#
#
# ---
# # Some definitions
#
# - ### **Sample space** $\Omega = [x_{1}, x_{2}]$
# - ### **Random variable** $Y(x) = 0$ if x is *tails* and $Y(x)=1$ if x is *heads*
#  + ### Maps abstract sample space to $\mathbb{R}$
# - ### **Event** is an outcome
#
# ---
# # Probability Rules
#
# - ### Probability of A occurring $P(A)$
# - ### Probability of B occurring $P(B)$
# - ### Probability of A occurring given B $P(A|B)$
# - ### Probability of A **AND** B occurring $P(A \cap B)$
# - ### Probability of A **OR** B occurring $P(A \cup B)$

# %% [markdown]
# ---
# # Probability Rules
#
# - ### **Dependence:**
#  + ### Does the outcome of one event influence another?

# %% [markdown]
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/idependent.png?raw=1)
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/dependent.png?raw=1)
#
# ---
#
# - ### Conditional probability of A **given** B has occurred
#  + ### $P(A|B) = \frac{P(B \cap A)}{P(B)}$
# - ### If  $P(A|B) = P(A)$ we can say A is independent of B
# - ### In an experimental context our model is $y \sim variable$
#  + ### $P(Y|variable)$
#
# ---
#
# - ### Probability of A **AND** B occurring
#  + ### $P(A \cap B) = P(A)P(B|A)$
# - ### Probability of A **OR** B occurring
#  + ### $P(A \cup B) = P(A) + P(B) - P(A \cap B)$
#
#
# ---
# # Example: flipping coins
#
# - ## What is the probability of two heads?
#  + ### Are flips independent?
#  + ### AND or OR?
#
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/flip.png?raw=1)
#
# ---
# # Probability Rules
#
# - ### **Total probability theorem**
#  + ### Assume  $C_{1}, C_{2}$ and $C_{3}$ partition the sample space
#  + ### $P(A) = \Sigma^{n}_{i=1}P(C_{n})P(A|C_{n})$
#
#
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/total.png?raw=1)

# %% [markdown]
# ---
# # Expectation
#
# -  ### You are walking down a dark alley after stats class and a biologist emerges from a crevice and asks you if you would like to place a bet. Heads or tails?
#
#  + ### If you guess heads and win you get 3 dollars
#  + ### If you are wrong you lose 2 dollars
# - ### **Do you take the bet?**

# %% [markdown]
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/coin.jpg?raw=1)
#
#
#
# ---
# # Expectation
#
# -  ### What is our expectation?
#
#
#
#
# | Outcome |  Heads | Tails|
# |---------|-------|------|
# | Probablilty| 0.5 | 0.5 |
# | Cost |+3|-2|
#
#
# ---
#
# # Expectation
#
# -  ### What is our expectation?
#  + ### **Expected value**  $E[X]$
#  + ### $E[X] = \Sigma^{n}_{i=1}P(x)x$
#
#
#
#
# | Outcome |  Heads | Tails|
# |---------|-------|------|
# |Probability | 0.5 | 0.5 |
# |Cost |+3|-2|
# |P(x)x|1.5|-1|
#
#
# ## Use the expectation to calculate your expected winnings or losses if you accept the bet.

# %%
# your code here

# %% [markdown]
# ---
#
# # Discrete distributions
#
# - ### Countable outcomes

# %%
success <- 0:20

plot(success, dbinom(success, size=20, prob=.3),type='h', ylab="Frequency",
     xlab="Number of successful flips", main="Binomial Distribution")
# Out:
# Plot with title “Binomial Distribution”

# %% [markdown]
# ---
# # Continuous distribution
#
#
# - ### Outcomes are not countable

# %%
library(ggplot2)
norm <- data.frame(y=dnorm(seq(from=-3, to=3, length.out=1000)), x=seq(from=-3, to=3, length.out=1000))
ggplot(norm, aes(x=x,y=y)) +
  geom_line() +
  theme_bw(base_size=18) + ylab("Likelihood") + ggtitle("Normal Distribution") +
  theme(panel.grid=element_blank(),
        panel.background=element_blank())
# Out:
# plot without title

# %% [markdown]
# ---
# # Moments of a distribution
#
# -  ### What are the descriptors of a distribution?
#  + ### Central tendency
#  + ### Spread

# %%
library(ggplot2)
norm <- data.frame(y=dnorm(seq(from=-3, to=3, length.out=1000)), x=seq(from=-3, to=3, length.out=1000))
ggplot(norm, aes(x=x,y=y)) +
  geom_line() +
  theme_bw(base_size=18) + ylab("Likelihood") + ggtitle("Normal Distribution") +
  theme(panel.grid=element_blank(),
        panel.background=element_blank())
# Out:
# plot without title

# %% [markdown]
# ---
# # Moments of a distribution
#
#
# - ### What are the descriptors of a distribution?
#  + ### Central tendency = $\mu =E[x]$
#  + ### Spread $\sigma^{2} = E[(x-\mu)^2]$

# %%
library(ggplot2)
norm <- data.frame(y=dnorm(seq(from=-3, to=3, length.out=1000)), x=seq(from=-3, to=3, length.out=1000))
ggplot(norm, aes(x=x,y=y)) +
  geom_line() +
  theme_bw(base_size=18) + ylab("Likelihood") + ggtitle("Normal Distribution") +
  theme(panel.grid=element_blank(),
        panel.background=element_blank())
# Out:
# plot without title

# %% [markdown]
# ---
# # Distribution of a random variable $X$ and $P(X)$
#
# - ### Probability of an outcome of $X$ can be determined from its distribution

# %%
set.seed(100)
ggplot(data.frame(x=rnorm(1000)), aes(x=x)) +
  geom_histogram(aes(y = after_stat(density)), binwidth=.2 ) + xlab("x value") +
  theme_bw(base_size=18) +
  theme(panel.background=element_blank(),
        panel.grid=element_blank()) +
  geom_vline(xintercept=1, linewidth=2, color="red") +
  geom_vline(xintercept=1.5, linewidth=2, color="red") +
  stat_function(fun = dnorm,
        args = list(mean = 0,
                    sd = 1),
        colour = 'blue', size = 3)
# Out:
# plot without title

# %% [markdown]
# ---
# # Monte Carlo method
#
# ### 1. Define input domain
# ### 2. Generate random values using probability distribution over domain
# ### 3. Perform calculation
# ### 4. Aggregate results
#
#
#
# ### $X \sim N(0,1)$ $P(X = x) \geq 1.5$
#
# ## To solve this analytically we would need to take the integral of the normal density from 1.5 to infinity.
# ## That is not trivial, but using Monte Carlo methods we can do this numerically with a few lines of code.
# ## In the coding cell below let's calculate this probability

# %%
n  = 10000
#the function rnorm samples from a normal distribution rnorm(sample size, mean, standard deviation)
x=rnorm(n,0,1)
threshold = 1.5
count=0
for(i in 1:n){
 # insert code to count how many values exceed the threshold and calculate the probability
    if(x[i]>threshold){
     count=count+1
    }
}
count/n
# Out:
# [1] 0.0682

# %% [markdown]
# ---
# # What if we only have a sample of a population?
#
# - ### We are not dealing with the population $\mu$ we now have and its estimate  $\overline{x} = \frac{\Sigma x_{i}}{n}$
# - ### We are not dealing with the population variance $\frac{\Sigma (x_{i}-\mu_x)^{2}}{n}$ we now have its estimate
#
# - ### These are MLE estimators, more on that later in the course...

# %%
set.seed(100)
dat = rnorm(100)
ggplot(data.frame(x=dat), aes(x=x)) +
  geom_histogram(aes(y = ..density..), binwidth=.2 ) + xlab("x value") +
  theme_bw(base_size=18) +
  theme(panel.background=element_blank(),
        panel.grid=element_blank()) +
  stat_function(fun = dnorm,
        args = list(mean = mean(dat),
                    sd = sqrt(var(dat))),
        colour = 'blue', size = 3)
# Out:
# plot without title

# %% [markdown]
# ---
# # Why take a sample?
#
#
# - ### Cheaper than measuring all individuals in the population (time and money)
# - ### Unable to sample all individuals in the population

# %%
library(ggplot2)
set.seed(100)
dat = rnorm(100)
ggplot(data.frame(x=dat), aes(x=x)) +
  geom_histogram(aes(y = ..density..),binwidth=.2 ) + xlab("x value") +
  theme_bw(base_size=18) +
  theme(panel.background=element_blank(),
        panel.grid=element_blank()) +
  stat_function(fun = dnorm,
        args = list(mean = mean(dat),
                    sd = sqrt(var(dat))),
        colour = 'blue', size = 3)
# Out:
# plot without title

# %% [markdown]
# ---
# # Central limit theorem
#
# **Central limit demo**
# ---
# # Central limit theorem
#
# - ### CLT states the sum of a large number of independent identically distributed random variables with a finite variance will be approximately normal.

# %%
library(ggplot2)
set.seed(100)
dat = rexp(10000)
ggplot(data.frame(x=dat), aes(x=x)) +
  geom_histogram(aes(y = ..density..), binwidth=.2 ) + xlab("x value") +
  ggtitle("Population Distribution") +
  theme_bw(base_size=18) +
  theme(panel.background=element_blank(),
        panel.grid=element_blank())
# Out:
# plot without title

# %% [markdown]
# ---
# # Central limit theorom
#
# - ### CLT states the sum of a large number of independent identically distributed random variables with a finite variance will be approximately normal.

# %%
set.seed(100)
samples <- c()
for(i in 1:1000){
  samples <- c(samples, mean(sample(dat, 30)))
}
ggplot(data.frame(x=samples), aes(x=x)) +
  geom_histogram(aes(y = ..density..), binwidth=.05 ) + xlab("x value") +
  ggtitle("1000 Means of 30 from Population") +
  theme_bw(base_size=18) +
  theme(panel.background=element_blank(),
        panel.grid=element_blank())
# Out:
# plot without title

# %% [markdown]
# ---
# # P-value
#
# - ### Given a distribution, what is the probability of observing a value as great or greater than some arbitrary value (**critical value is commonly 0.05**)
#
#
# ![](https://github.com/krr73/PLSCI-7201/blob/main/Modules/Module2/Lecture/images/pval.jpg?raw=1)
#
#
# ---
# # The Null Hypothesis
#
# - ### The hypothesis that the observation is due to chance alone.
#
# - ### The p-value is  calculated for a null distribution, which is the distribution assuming the null hypothesis
